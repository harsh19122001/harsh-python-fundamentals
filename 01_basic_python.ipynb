# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # python variable = identifier = object
# # syntax (variable = value)

# %%
V=8
V
# Out:
# 8

# %% [markdown]
# # RULES TO DEFINE VARIABLE

# %%
var=8
VAR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 var=8
# ----> 2 VAR
#
# NameError: name 'VAR' is not defined

# %%
var
# Out:
# 8

# %%
v@=16
v@
# Out:
#   Cell In[8], line 2
#     v@
#       ^
# SyntaxError: invalid syntax

# %%
v_=20
v_
# Out:
# 20

# %%
1var=25
1var
# Out:
#   Cell In[11], line 1
#     1var=25
#     ^
# SyntaxError: invalid decimal literal

# %%
var1=24
var1
# Out:
# 24

# %%
'1var'=9
'1var'
# Out:
#   Cell In[13], line 1
#     '1var'=9
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
import keyword
keyword.list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import keyword
# ----> 2 keyword.list
#
# AttributeError: module 'keyword' has no attribute 'list'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # python datatypes
# - int
# - float
# - boolean
# - string
# - complex

# %%
i=5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
f=110.95
f
# Out:
# 110.95

# %%
type(f)
# Out:
# float

# %%
i
f
# Out:
# 110.95

# %%
print(i)
print(f)
# Out:
# 5
# 110.95

# %%
i+f
# Out:
# 115.95

# %%
i-f
# Out:
# -105.95

# %%
i*f
# Out:
# 554.75

# %% [markdown]
# # bool

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
False*True
# Out:
# 0

# %%
True/True
# Out:
# 1.0

# %%
True//True
# Out:
# 1

# %%
s='hello'
s
# Out:
# 'hello'

# %%
s1="hello"
s1
# Out:
# 'hello'

# %%
s2="'hello'"
s2
# Out:
# "'hello'"

# %%
s3=''' hello
            team '''
s3
# Out:
# ' hello\n            team '

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10+20j
d=20+30j
print(c+d)
# Out:
# (30+50j)

# %%
print(c+d)
# Out:
# (30+50j)

# %%
print(c-d)
# Out:
# (-10-10j)

# %%
print(c*d)
# Out:
# (-400+700j)

# %%
print(c/d)
# Out:
# (0.6153846153846154+0.0769230769230769j)

# %% [markdown]
# # Python vaiable completed
# # Python datatype completed

# %% [markdown]
# # 16th
#
# - python intro
# - python interpreter,compplier,ide
# - which ide we installed
# - how to check python version
# - name is called variable(variable == object == identifer)
# - python datatype
# - demo(who learned, what topics,placement,class,duration,project,capstone,certificate,roadmap.
# - course syllabus)
# - introduction to function & argument

# %% [markdown]
# # Type Casting == convert one data type to other data type

# %% [markdown]
# # All other data type to integer

# %%
int(2.4)
# Out:
# 2

# %%
int(2.4,3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(2.4,3.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # All other data type to float

# %%
float(10)
# Out:
# 10.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('25')
# Out:
# 25.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 float(1+5j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # All other data type to string

# %%
str(10)
# Out:
# '10'

# %%
str(10.5)
# Out:
# '10.5'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(10+20j)
# Out:
# '(10+20j)'

# %% [markdown]
# # All other data type to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10.5)
# Out:
# (10.5+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # All other data type to boolean

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(10)
# Out:
# True

# %%
bool(20)
# Out:
# True

# %%
bool(0.1)
# Out:
# True

# %%
bool(5.5)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('True')
# Out:
# True

# %%
bool('False')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(10+20j)
# Out:
# True

# %% [markdown]
# # how to use e

# %%
f = 1e0
f
# Out:
# 1.0

# %%
f1 = 2e1
f1
# Out:
# 20.0

# %%
f2 = 2.4e2
f2
# Out:
# 240.0

# %% [markdown]
# # id is = addressof  the memory allocation

# %%
a=20
a
# Out:
# 20

# %%
id(a)
# Out:
# 140724353086984

# %%
p=10
q=10
r=10

# %%
print(id(p))
print(id(q))
print(id(r))
# Out:
# 140724353086664
# 140724353086664
# 140724353086664

# %% [markdown]
# # Indexing
# - forward indexing : from left to right
# - backward indexing : from right to left
# - step indexing :

# %%
str='hello'

# %%
print(str[0])
print(str[1])
print(str[2])
print(str[3])
print(str[4])
print(str[len])
# Out:
# h
# e
# l
# l
# o
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 6
#       4 print(str[3])
#       5 print(str[4])
# ----> 6 print(str[len])
#
# TypeError: string indices must be integers, not 'builtin_function_or_method'

# %%
print(str[-1])
print(str[-2])
print(str[-3])
print(str[-4])
print(str[-5])
# Out:
# o
# l
# l
# e
# h

# %%
str='hello'

# %%
len[str]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 len[str]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
str
# Out:
# 'hello'

# %%
len(str)
# Out:
# 5

# %% [markdown]
# # Slicing
# - forward from left to right
# - backward from right to left
# - step slicing depends on positive or negative & skiping the element according to 3rd numnber

# %%
str='hello'

# %%
str
# Out:
# 'hello'

# %%
str[1:3]
# Out:
# 'el'

# %%
str
# Out:
# 'hello'

# %%
str[0:4]
# Out:
# 'hell'

# %%
str[0:6]
# Out:
# 'hello'

# %%
s='hellopython'

# %%
s
# Out:
# 'hellopython'

# %%
s[0:10:3]
# Out:
# 'hlyo'

# %%
s
# Out:
# 'hellopython'

# %%
s[1:8:2]
# Out:
# 'elpt'

# %%
s
# Out:
# 'hellopython'

# %%
s[::1]
# Out:
# 'hellopython'

# %%
s[::2]
# Out:
# 'hloyhn'

# %%
s
# Out:
# 'hellopython'

# %%
s[::3]
# Out:
# 'hlyo'

# %% [markdown]
# # String concatenation - means addition of strings

# %%
s1='Hello'
s2='Asif'
print(s1+s2)
# Out:
# HelloAsif

# %% [markdown]
# # Python operator

# %% [markdown]
# # Arithmetic operator

# %%
x1=10
y1=5

# %%
x1,y1 = 10,5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
2**3
# Out:
# 8

# %% [markdown]
# # Assignment operator

# %%
x=2

# %%
x=x+2 #if u want increased by 2

# %%
x
# Out:
# 6

# %%
x +=2
x
# Out:
# 8

# %%
x +=2
x
# Out:
# 12

# %%
x +=2
x
# Out:
# 5.5

# %%
x -=2
x
# Out:
# 1.5

# %%
x /=2
x
# Out:
# 1.375

# %% [markdown]
# # Unary operator
# - unary means 1 || binary means 2
# - here we are applying unary minus operator (-) on the operand n; the value m becomes -7,which indicates it as a negative value

# %%
n = 7 #negatation
n
# Out:
# 7

# %%
m = -(n)
m

# %% [markdown]
# # Relational operator
#
# we are using this operator for comparing

# %%
a = 5

# %%
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
# a = b #we cannot use = operator that means it is assigning

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# hear if i change b = 6
b = 5

# %%
a == b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a > b
# Out:
# False

# %%
b > a
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
b = 7

# %%
a != b
# Out:
# True

# %% [markdown]
# # Logical Operator
#
#  logical operator you need to understand to understand about true & false table.
#  3 important part of logical operator is -- AND,OR,NOT

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %% [markdown]
# # Binary

# %%
bin(25)
# Out:
# '0b11001'

# %%
0b11001
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25)
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
0x19
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
hex(1)
# Out:
# '0x1'

# %% [markdown]
# # Bitwise operator
#
# - complement operator ~
# - bitwise AND &
# - bitwise OR  |
# - bitwise XOR ^
# - Left shif (<<)
# - Right shift (>>)

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
print(35&40)
print(35|40)
# Out:
# 32
# 43

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25 ^ 30
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
10 << 1
# Out:
# 20

# %%
10 << 2
# Out:
# 40

# %%
10 >> 1
# Out:
# 5

# %%
10 >> 2
# Out:
# 2

# %%
10 >> 3
# Out:
# 1

# %% [markdown]
# # print()

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python',1+2j,True,2.3,[2,5])
# Out:
# 10
# 10 20
# python
# 10 20 python (1+2j) True 2.3 [2, 5]

# %%
num1 = 20
num2 = 30 
add = num1 + num2
print('the addition of',num1,'and',num2,'is =',add)
# Out:
# the addition of 20 and 30 is = 50

# %%
name = 'Python'
age = 20
city = 'Hyderabad'
#hello my name is python and i am 10 years old from hyderabad
print('hello my name is',name,'and i am',age,'years old from hyderabad')
# Out:
# hello my name is Python and i am 20 years old from hyderabad

# %%
#print format method 
num1 = 10
num2 = 20
add = num1 + num2
print('the addition of {} and {} is = {}'.format(num1,num2,add))
# Out:
# the addition of 10 and 20 is = 30

# %%
#print f string method
num1 = 20
num2 = 30
add = num1 + num2
print(f'the addition of {num1} and {num2} is= {add}')
# Out:
# the addition of 20 and 30 is= 50

# %%
#end statement
print('hello',end =' ') #first statement
print('good morning') #second statement
# Out:
# hello good morning

# %%
#seprator
print('hello','hai','how are you', sep = '---> ')
# Out:
# hello---> hai---> how are you

# %%
printlen(l1)
len(l2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 len(l1)
#       2 len(l2)
#
# NameError: name 'l1' is not defined

# %%
l1[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 l1[:]
#
# NameError: name 'l1' is not defined

# %% [markdown]
# # Basic python

# %%
name = 'fine'
name
# Out:
# 'fine'

# %%
name[1:4]
# Out:
# 'ine'

# %%
newname = 'd'+name[1:4]

# %%
newname
# Out:
# 'dine'

# %%
PI  = 3.14 #in math this is always constant but python we can change
PI
# Out:
# 3.14

# %%
PI = 3.15
PI
# Out:
# 3.15

# %% [markdown]
# # Swap variable

# %%
a = 5
b = 6

# %%
a = b  #In this scneario we lost the value 5
b = a

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
a1 = 7
b1 = 8

# %%
temp = a1
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 7

# %%
a2 = 5
b2 = 6

# %%
#swap variable formulas
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 -b2

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
 a3 = 8
b3 = 9

# %%
a3,b3 = b3,a3

# %%
print(a3)
print(b3)
# Out:
# 9
# 8

# %% [markdown]
# # import math function

# %%
x = sqrt(25) #sqrt is inbuild function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math #math is module

# %%
x = math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(2.9)) #floor - minium or least value
# Out:
# 2

# %%
 print(math.ceil(2.9)) #ceil - maximum or highest value
# Out:
# 3

# %%
print(math.pow(3,4))
# Out:
# 81.0

# %%
print(math.pi) #these are constant
# Out:
# 3.141592653589793

# %%
print(math.e) #these are constant
# Out:
# 2.718281828459045

# %%
import math as m

# %%
print(m.sqrt(10))
# Out:
# 3.1622776601683795

# %%
from math import sqrt,pow #math has many functiob if you want to call specific function then you use from
print(pow(2,3))
print(sqrt(20))
# Out:
# 8.0
# 4.47213595499958

# %%
round(pow(2,3))
# Out:
# 8
